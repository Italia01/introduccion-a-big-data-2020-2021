# %% [markdown]
# # importamos la libreria pandas

# %%
import pandas as pd

# %% [markdown]
# # extraereamos los datos de la API

# %%
df = pd.read_json("https://juanitapechutmetropolitana.000webhostapp.com/API/index.php/Controlador_API/datos_ver_organico")

# %%
dl = pd.read_json("https://juanitapechutmetropolitana.000webhostapp.com/API/index.php/Controlador_API/datos_ver_inorganico")

# %% [markdown]
# # comprobamos el guardado de los datos de basura organica e inorganica

# %%
df
# Out:
#         hora  cantidadBasura
# 0   07:27:27              30
# 1   07:08:27              25
# 2   06:41:35              20
# 3   06:20:35              10
# 4   06:06:44               0
# 5   14:38:44              30
# 6   15:04:56              25
# 7   14:46:56              20
# 8   14:40:09              15
# 9   14:05:08              10
# 10  13:47:08               0
# 11  13:02:08              30
# 12  12:28:19              25
# 13  12:01:19              20
# 14  11:45:25              18
# 15  11:28:25              12
# 16  11:04:05               0
# 17  10:20:05              30
# 18  09:42:18              25
# 19  09:33:18              20
# 20  07:39:25              15
# 21  07:03:25              10
# 22  06:39:31               5
# 23  06:31:31               0
# 24  01:05:23              20
# 25  00:42:59              15
# 26  10:20:00               1
# 27  10:15:00               3
# 28  10:10:00               5
# 29  10:08:00               8
# 30  10:05:00               9
# 31  10:00:00              10
# 32  08:15:00              15
# 33  08:00:00              18
# 34  07:50:36              20
# 35  07:50:36              20
# 36  07:15:36              28
# 37  07:00:36              30
# 38  07:15:36              28
# 39  07:00:36              30
# 40  00:52:36              30

# %%
dl
# Out:
#         hora  cantidadBasura
# 0   17:00:01              30
# 1   14:11:01              25
# 2   15:48:09              20
# 3   15:07:09              15
# 4   14:45:08              10
# 5   14:28:08               0
# 6   13:39:26              30
# 7   13:06:17              25
# 8   12:50:17              20
# 9   12:06:03              14
# 10  11:24:03               7
# 11  09:06:37               0
# 12  08:22:37              30
# 13  07:21:00              25
# 14  06:51:00              19
# 15  06:36:29              13
# 16  06:23:39               6
# 17  06:29:30               2
# 18  06:23:30               0
# 19  11:17:08              30
# 20  08:44:08              25
# 21  08:19:12              23
# 22  08:07:12              20
# 23  07:49:34              16
# 24  07:39:30              13
# 25  07:28:24              10
# 26  07:14:15               5
# 27  06:23:51               3
# 28  06:10:51               0
# 29  06:28:33               3
# 30  06:07:33               0
# 31  11:06:02               0
# 32  10:34:06              34
# 33  10:15:00              30
# 34  09:25:36              28
# 35  09:00:36              26
# 36  08:25:36              23
# 37  08:00:00              19
# 38  07:15:36              15
# 39  07:00:36               9
# 40  01:16:38               5
# 41  01:16:30              15
# 42  00:42:36              15
# 43  08:40:00               0
# 44  08:30:00               2
# 45  08:15:00               5
# 46  08:00:00               8
# 47  07:40:00              10
# 48  07:35:00              15
# 49  07:30:00              18
# 50  07:20:00              22
# 51  07:15:36              25
# 52  07:10:36              27
# 53  07:05:36              28
# 54  07:00:36              30
# 55  11:27:06              30
# 56  11:25:40              30
# 57  00:54:28              30

# %% [markdown]
# # veremos el contenido de las columnas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hora            41 non-null     object
#  1   cantidadBasura  41 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 784.0+ bytes

# %%
dl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hora            58 non-null     object
#  1   cantidadBasura  58 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %% [markdown]
# # podemos visualizar que las unicas columnas que encontramos son la hora y la cantidad de basura guardada

# %%
df.describe()
# Out:
#        cantidadBasura
# count       41.000000
# mean        16.707317
# std         10.025577
# min          0.000000
# 25%         10.000000
# 50%         18.000000
# 75%         25.000000
# max         30.000000

# %%
dl.describe()
# Out:
#        cantidadBasura
# count       58.000000
# mean        16.172414
# std         10.693723
# min          0.000000
# 25%          6.250000
# 50%         15.500000
# 75%         25.000000
# max         34.000000

# %% [markdown]
# # podemos ver la cantidad de maximos y minimos de basura que esta en los dos botes, lo que nos ayuda a veriguiar los intervalos de tiempo de los maximos y los minimos cambios de los botes.

# %%
relation = df[['cantidadBasura']] + dl[['cantidadBasura']]

# %% [markdown]
# # buscamos la relacion que tiene los datos de la basura organica con la inorganica.

# %%
relation
# Out:
#     cantidadBasura
# 0             60.0
# 1             50.0
# 2             40.0
# 3             25.0
# 4             10.0
# 5             30.0
# 6             55.0
# 7             45.0
# 8             35.0
# 9             24.0
# 10             7.0
# 11            30.0
# 12            55.0
# 13            45.0
# 14            37.0
# 15            25.0
# 16             6.0
# 17            32.0
# 18            25.0
# 19            50.0
# 20            40.0
# 21            33.0
# 22            25.0
# 23            16.0
# 24            33.0
# 25            25.0
# 26             6.0
# 27             6.0
# 28             5.0
# 29            11.0
# 30             9.0
# 31            10.0
# 32            49.0
# 33            48.0
# 34            48.0
# 35            46.0
# 36            51.0
# 37            49.0
# 38            43.0
# 39            39.0
# 40            35.0
# 41             NaN
# 42             NaN
# 43             NaN
# 44             NaN
# 45             NaN
# 46             NaN
# 47             NaN
# 48             NaN
# 49             NaN
# 50             NaN
# 51             NaN
# 52             NaN
# 53             NaN
# 54             NaN
# 55             NaN
# 56             NaN
# 57             NaN

# %% [markdown]
# # estos datos nos ayudaran a buscar las relaciones entre los mobimientos de los dos botes.

# %%
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt 
# %matplotlib inline

# %% [markdown]
# # aqui ya importamos las librerias para las graficas.

# %%
sns.pairplot(relation, kind='reg')
plt.show()

# %% [markdown]
# # aqui veremos de una manera mas grafica la relacion que tiene una basura con la otra.

# %%
sns.distplot(df.cantidadBasura)

# %% [markdown]
# # aqui podremos observar el mobimiento que tiene la basura entre los interbalos establecidos.

# %%
sns.lmplot(x='hora', y='cantidadBasura', data=df)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-49-10683b9d6b1f> in <module>
# ----> 1 sns.lmplot(x='hora', y='cantidadBasura', data=df)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     615         scatter_kws=scatter_kws, line_kws=line_kws,
#     616         )
# --> 617     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     618
#     619     # Add a legend
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     831
#     832             # Draw the plot
# --> 833             self._facet_plot(func, ax, args, kwargs)
#     834
#     835         # Finalize the annotations and layout
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     849
#     850         # Draw the plot
# --> 851         func(*plot_args, **plot_kwargs)
#     852
#     853         # Sort out the supporting information
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     363
#     364         if self.fit_reg:
# --> 365             self.lineplot(ax, line_kws)
#     366
#     367         # Label the axes
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/regression.py in lineplot(self, ax, kws)
#     406         """Draw the model."""
#     407         # Fit the regression model
# --> 408         grid, yhat, err_bands = self.fit_regression(ax)
#     409         edges = grid[0], grid[-1]
#     410
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/regression.py in fit_regression(self, ax, x_range, grid)
#     194                 else:
#     195                     x_min, x_max = ax.get_xlim()
# --> 196             grid = np.linspace(x_min, x_max, 100)
#     197         ci = self.ci
#     198
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     118     # Convert float/complex array scalars to float, gh-3504
#     119     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 120     start = asanyarray(start) * 1.0
#     121     stop  = asanyarray(stop)  * 1.0
#     122
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')

# %% [markdown]
# # aqui hemos graficado la interseccion de la hora con la cantidad de basura lo que nos puede ayudar a detectar las horas pico en las que el bote se usa con mayor frecuencia.

# %%
df.corr()
# Out:
#                 cantidadBasura
# cantidadBasura             1.0

# %%
from io import StringIO  
import boto3

 

bucket = 'juana' 
csv_buffer = StringIO()
df.to_csv(csv_buffer)

 

s3_resource = boto3.resource('s3')
s3_resource.Object(bucket, 'datosorganico.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': 'DPQZM2Z5WP9D7Q4A',
#   'HostId': '3aBh25IpvBMGGgu0QgfqhinmkMKufNZizRAapIpz9N1+HcLyPEFERcbntxZBbFfJ5au0YNPDk6o=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '3aBh25IpvBMGGgu0QgfqhinmkMKufNZizRAapIpz9N1+HcLyPEFERcbntxZBbFfJ5au0YNPDk6o=',
#    'x-amz-request-id': 'DPQZM2Z5WP9D7Q4A',
#    'date': 'Mon, 08 Mar 2021 06:40:59 GMT',
#    'etag': '"bfd17eb52d9d8e30f46275543bd83673"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"bfd17eb52d9d8e30f46275543bd83673"'}

# %% [markdown]
# # importamos la libreria y creamos a un bocket  y lo pasamos a un archivo dentro del bucket de la basura organica

# %%
dato = pd.read_csv("https://juana.s3.amazonaws.com/datosorganico.csv")

# %% [markdown]
# # extraemos el contenido con la url del bocket con los datos de la basura organica

# %%
dato
# Out:
#     Unnamed: 0      hora  cantidadBasura
# 0            0  07:27:27              30
# 1            1  07:08:27              25
# 2            2  06:41:35              20
# 3            3  06:20:35              10
# 4            4  06:06:44               0
# 5            5  14:38:44              30
# 6            6  15:04:56              25
# 7            7  14:46:56              20
# 8            8  14:40:09              15
# 9            9  14:05:08              10
# 10          10  13:47:08               0
# 11          11  13:02:08              30
# 12          12  12:28:19              25
# 13          13  12:01:19              20
# 14          14  11:45:25              18
# 15          15  11:28:25              12
# 16          16  11:04:05               0
# 17          17  10:20:05              30
# 18          18  09:42:18              25
# 19          19  09:33:18              20
# 20          20  07:39:25              15
# 21          21  07:03:25              10
# 22          22  06:39:31               5
# 23          23  06:31:31               0
# 24          24  01:05:23              20
# 25          25  00:42:59              15
# 26          26  10:20:00               1
# 27          27  10:15:00               3
# 28          28  10:10:00               5
# 29          29  10:08:00               8
# 30          30  10:05:00               9
# 31          31  10:00:00              10
# 32          32  08:15:00              15
# 33          33  08:00:00              18
# 34          34  07:50:36              20
# 35          35  07:50:36              20
# 36          36  07:15:36              28
# 37          37  07:00:36              30
# 38          38  07:15:36              28
# 39          39  07:00:36              30
# 40          40  00:52:36              30

# %% [markdown]
# # ahora podemos ver los datos de la basura oraganica que tenemos en el archivo csv

# %%
from io import StringIO  
import boto3

 

bucket = 'juana' 
csv_buffer = StringIO()
dl.to_csv(csv_buffer)

 

s3_resource = boto3.resource('s3')
s3_resource.Object(bucket, 'datosinorganico.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': 'TPTGKQJ33C7YWGMD',
#   'HostId': 'jxB43hydZO1sKAUX0DjumIsB2EPvv7fuO3nGAtHuMSgmbOPhaDI98Cyg78SX42/6AzFpKG006qo=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'jxB43hydZO1sKAUX0DjumIsB2EPvv7fuO3nGAtHuMSgmbOPhaDI98Cyg78SX42/6AzFpKG006qo=',
#    'x-amz-request-id': 'TPTGKQJ33C7YWGMD',
#    'date': 'Mon, 08 Mar 2021 06:42:41 GMT',
#    'etag': '"90999c71cf2d0cac592ee6bd6184bf6e"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"90999c71cf2d0cac592ee6bd6184bf6e"'}

# %% [markdown]
# # importamos la libreria y creamos a un bocket  y lo pasamos a un archivo dentro del bucket de la basura inorganica

# %%
datas = pd.read_csv("https://juana.s3.amazonaws.com/datosinorganico.csv")

# %% [markdown]
# # extraemos el contenido con la url del bocket con los datos de la basura inorganica

# %%
datas
# Out:
#     Unnamed: 0      hora  cantidadBasura
# 0            0  17:00:01              30
# 1            1  14:11:01              25
# 2            2  15:48:09              20
# 3            3  15:07:09              15
# 4            4  14:45:08              10
# 5            5  14:28:08               0
# 6            6  13:39:26              30
# 7            7  13:06:17              25
# 8            8  12:50:17              20
# 9            9  12:06:03              14
# 10          10  11:24:03               7
# 11          11  09:06:37               0
# 12          12  08:22:37              30
# 13          13  07:21:00              25
# 14          14  06:51:00              19
# 15          15  06:36:29              13
# 16          16  06:23:39               6
# 17          17  06:29:30               2
# 18          18  06:23:30               0
# 19          19  11:17:08              30
# 20          20  08:44:08              25
# 21          21  08:19:12              23
# 22          22  08:07:12              20
# 23          23  07:49:34              16
# 24          24  07:39:30              13
# 25          25  07:28:24              10
# 26          26  07:14:15               5
# 27          27  06:23:51               3
# 28          28  06:10:51               0
# 29          29  06:28:33               3
# 30          30  06:07:33               0
# 31          31  11:06:02               0
# 32          32  10:34:06              34
# 33          33  10:15:00              30
# 34          34  09:25:36              28
# 35          35  09:00:36              26
# 36          36  08:25:36              23
# 37          37  08:00:00              19
# 38          38  07:15:36              15
# 39          39  07:00:36               9
# 40          40  01:16:38               5
# 41          41  01:16:30              15
# 42          42  00:42:36              15
# 43          43  08:40:00               0
# 44          44  08:30:00               2
# 45          45  08:15:00               5
# 46          46  08:00:00               8
# 47          47  07:40:00              10
# 48          48  07:35:00              15
# 49          49  07:30:00              18
# 50          50  07:20:00              22
# 51          51  07:15:36              25
# 52          52  07:10:36              27
# 53          53  07:05:36              28
# 54          54  07:00:36              30
# 55          55  11:27:06              30
# 56          56  11:25:40              30
# 57          57  00:54:28              30

# %% [markdown]
# # ahora podemos ver los datos que tenemos en el archivo csv
